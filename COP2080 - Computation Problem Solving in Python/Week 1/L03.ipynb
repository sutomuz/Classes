# %% [markdown]
# # Conditional Programming & Iteration

# %% [markdown]
# ## Basic If Statements

# %%
#conditional.2.py
late = False
if late:
    print('I need to call my manager!')
else:
    print('no need to call my manager...')
# Out:
# no need to call my manager...

# %%
# ternary.py
# ternary operator
order_total = 75
discount = 25 if order_total > 100 else 0
print(order_total, discount)
# Out:
# 75 0

# %%
# ternary operator 
color = 'red'
new_value = 'blue' if color == 'red' else 'white'
print(f'new color is {new_value}')
# Out:
# new color is blue
