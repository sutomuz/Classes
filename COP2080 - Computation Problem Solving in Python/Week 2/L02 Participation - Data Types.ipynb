# %% [markdown]
# # L02 Participation - Data Types

# %% [markdown]
# ## Background
# Explore using data types and data structures

# %% [markdown]
# ## Procedure
# Run the associated code in pycharm, command line, idle or colab google. Answer questions and copy/paste or screen shot answers.

# %% [markdown]
# **1.** Run the Python code of the following. Note the use of string formatting and length functions.
# a. The first __ letters are dsplayed
# b. The _ __ ___ letters are displayed
# c. Copy/paste your code output below.

# %%
# Print the first __ letters of a string, followed by ..., followed by the 
# ___ _ letters of a string.
#

# %%
# Initialize the string.
string = "Polytechnic"

# Display the result.
print("%s...%s" % (string[0 : 3], string[len(string) - 3 : len(string)]))
# Out:
# Pol...nic

# %% [markdown]
# **2.** Run the Python code of the following.  Note the use of user input casting variables.
# a. What happens if you type “cat” into the input field instead of a number? _____
# b. Enter 88.99 into the input. Copy/Paste input below
#       _______
# c. Swap the commented print line at the end of the program with the one above it. The f-string is more concise; is there a change in in the output? __________

# %%
## Question 2
# Extract the dollars and cents from a floating-point price
# Typecase the user input as a float

# Gather input from the user.
price = float(input("Enter a price: "))

# Compute the dollars and the cents.
# Cast price and dollars as an integer
dollars = int(price)
cents = int((price - dollars) * 100 + 0.5)

# Display the results
print(dollars, "dollars", cents, "cents")

# Comment the above line
# Uncomment the line beneath to use concise f-string
# print(f"{dollars} dollars {cents} cents")
# Out:
# Enter a price:  88.99
# 88 dollars 99 cents

# %% [markdown]
# **3.** Run the python code of the following. Use List methods to manipulate.
# a. What does names.pop do to the list? ___
# b. Where does the append method place 'Jorge'? _____
# c. What is the final command needed to display a sorted names list? ______________
# d. Show the output from this program with sorting: ________

# %%
## Question 3
# Create a list. List methods allow you to manipulate
names = ['Fritz']
names.insert(1, 'Ann')
names.insert(0, 'Melina')
names.pop(2)
names.append('Jorge')
# Add the command to display the contents of the names list
print(sorted(names))
# Out:
# ['Fritz', 'Jorge', 'Melina']

# %% [markdown]
# **4.** Run the python code of the following.
# a. Copy and paste the output from running below:

# %%
## Question 4
# Create a dictionary of the key:value pairs
contacts = {'Jenny': 8675309, 'James': 5551212}
print(*contacts) # asterisk unpacks argument
print('Jennys number is', contacts['Jenny'])
brian = contacts.get('James') # get the value of 
# james key and assign to brian
print('Brian has new number', brian)
# Out:
# Jenny James
# Jennys number is 8675309
# Brian has new number 5551212
