# %% [markdown]
# # L09 Participation Assignment – Super Class

# %% [markdown]
# ## Background
# Implement a simple class

# %% [markdown]
# ## Procedure
# Answer the following questions with cut and paste or screenshots.

# %% [markdown]
# **1.**	Implement the code below. To avoid duplication in the __init__ for Ebok, replace the duplicated sub class defintions in Ebook with a super() class. Show your code:

# %%
# Given Code
# oop/super.duplication.py
class Book:
    def __init__(self, title, publisher, pages):
        self.title = title
        self.publisher = publisher
        self.pages = pages
        
class Ebook(Book):
    def __init__(self, title, publisher, pages, format_):
        self.title = title
        self.publisher = publisher
        self.pages = pages
        self.format_ = format_

ebook = Ebook(
    'Learn Python Programming', 'Packt Publishing', 500, 'PDF')
print(ebook.title)   
print(ebook.publisher)   
print(ebook.pages)   
print(ebook.format_)
# Out:
# Learn Python Programming
# Packt Publishing
# 500
# PDF

# %%
# Fixed Code
# oop/super.duplication.py
class Book:
    def __init__(self, title, publisher, pages):
        self.title = title
        self.publisher = publisher
        self.pages = pages

class Ebook(Book):
    def __init__(self, title, publisher, pages, format_):
        super().__init__(title, publisher, pages)
        self.format_ = format_

ebook = Ebook(
    'Learn Python Programming', 'Packt Publishing', 500, 'PDF')
print(ebook.title)
print(ebook.publisher)
print(ebook.pages)
print(ebook.format_)
# Out:
# Learn Python Programming
# Packt Publishing
# 500
# PDF

# %% [markdown]
# **2.**	 Usie the dunder method with __str__ to  convert the object to string and make it human readable. This is used for creating a user-friendly output and dsiplaying the object as a string.
# Use this code:

# %% [markdown]
# ```
# class Ocean:
#
#     def __init__(self, sea_creature_name, sea_creature_size):
#         self.name = sea_creature_name
#         self.size = sea_creature_size
#
# # placeholder
#
# # another placeholder
#
# c = Ocean('Jellyfish', '30 cm')
#
#
# Add this string method to the function at the placeholder:
# def __str__(self):
#         return f'The creature type is {self.name} and the age is {self.size}'
#
# Now print it:
# print(str(c))
# ```

# %%
# Fixed Code
class Ocean:
    def __init__(self, sea_creature_name, sea_creature_size):
        self.name = sea_creature_name
        self.size = sea_creature_size

    def __str__(self):
        return f'The creature type is {self.name} and the size is {self.size}'

c = Ocean('Jellyfish', '30 cm')

print(str(c))
# Out:
# The creature type is Jellyfish and the size is 30 cm

# %% [markdown]
# **3.**	Use the Ocean class and add another dunder method as __repr__. This is used to return a string object typically for debugging and development testing purposes.

# %% [markdown]
# ```
# Add this rpr method to the function at the placeholder:
# def __repr__(self):
#     return f'Ocean(\'{self.name}\', {self.size})'
#
# Then print it:
# print(repr(c))
# ```

# %%
# Fixed Code
class Ocean:
    def __init__(self, sea_creature_name, sea_creature_size):
        self.name = sea_creature_name
        self.size = sea_creature_size

    def __str__(self):
        return f'The creature type is {self.name} and the size is {self.size}'

    def __repr__(self):
        return f"Ocean('{self.name}', '{self.size}')"

c = Ocean('Jellyfish', '30 cm')

print(repr(c))
# Out:
# Ocean('Jellyfish', '30 cm')

# %% [markdown]
# **4.** Copy the code below:

# %% [markdown]
# ```
# # some_inheritance.py
# class Engine:
#   def start(self):
#       return
#   def stop(self):
#       pass
# class ElectricEngine(Engine):  # Is-A Engine
#   pass
# class V8Engine(Engine):  # Is-A Engine
#   pass
#
# class Car:
#     engine_cls = Engine
#     def __init__(self):
#         self.engine = self.engine_cls()  # Has-A Engine
#     def start(self):
#         print(
#             'Starting engine {0} for car {1}... Wroom, wroom!'
#             .format(
#                 self.engine.__class__.__name__,
#                 self.__class__.__name__)
#         )
#         self.engine.start()
#     def stop(self):
#         self.engine.stop()
# class RaceCar(Car):  # Is-A Car
#     engine_cls = V8Engine
# class CityCar(Car):  # Is-A Car
#     engine_cls = ElectricEngine
# class F1Car(RaceCar):  # Is-A RaceCar and also Is-A Car
#     pass  # engine_cls same as parent
# car = Car()
# racecar = RaceCar()
# citycar = CityCar()
# f1car = F1Car()
# cars = [car, racecar, citycar, f1car]
# for car in cars:
#     car.start()
#
# Compose a Headlights Class is in a HAS-A relationship with Car.  Implement this into Car.
# class Headlights:
#   def lights_on(self):
#     print('Lights are on')
#
#   def lights_off(self):
#     print('lights are off')
#
# ```

# %%
# some_inheritance.py
class Engine:
    def start(self):
        return
    def stop(self):
        pass
class ElectricEngine(Engine):  # Is-A Engine
    pass
class V8Engine(Engine):  # Is-A Engine
    pass

class Car:
    engine_cls = Engine
    def __init__(self):
        self.engine = self.engine_cls()  # Has-A Engine
        self.headlights = Headlights()   
    def start(self):
        print(
            'Starting engine {0} for car {1}... Vroom, vroom!'
            .format(self.engine_cls.__name__, self.__class__.__name__)
        )
        self.engine.start()
        self.headlights.lights_on()    
    def stop(self):
        self.engine.stop()
        self.headlights.lights_off()     
class RaceCar(Car):  # Is-A Car
    engine_cls = V8Engine
class CityCar(Car):  # Is-A Car
    engine_cls = ElectricEngine
class F1Car(RaceCar):  # Is-A RaceCar and also Is-A Car
    pass
class Headlights:
    def lights_on(self):
        print('Lights are on')
    def lights_off(self):
        print('Lights are off')
    
car = Car()
racecar = RaceCar()
citycar = CityCar()
f1car = F1Car()
cars = [car, racecar, citycar, f1car]
for car in cars:
    car.start()
# Out:
# Starting engine Engine for car Car... Vroom, vroom!
# Lights are on
# Starting engine V8Engine for car RaceCar... Vroom, vroom!
# Lights are on
# Starting engine ElectricEngine for car CityCar... Vroom, vroom!
# Lights are on
# Starting engine V8Engine for car F1Car... Vroom, vroom!
# Lights are on
