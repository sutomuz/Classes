# %% [markdown]
# # L04 Participation - Functions

# %% [markdown]
# ## Background
# Explore the use of functions.

# %% [markdown]
# ## Procedure
# Answer the following questions

# %% [markdown]
# **1.** Preview the following code that calculates addig tax to the price of an item. Copy the code to a Python file and ensure it works as expected.

# %%
## tax.no_function.py
done = False
while not done:
    sentinel = str.upper(input(f'Enter Q for quit or any other key to compute tax '))
    if sentinel == 'Q':
        done = True
        print(sentinel, done)
        continue
    else:
        print("Compute tax")
    price = float(input('What is the price '))
    tax = float(input('What is the tax rate? '))
    calculated_price = price * (100 + tax) / 100
    print(f'The calculated price is {calculated_price}')
# Out:
# Enter Q for quit or any other key to compute tax  q
# Q True

# %% [markdown]
# **2.** Rewrite the tax.no_function.py module using a function for get_inputs() and calculate_price_with_tax(). Paste your code here:

# %%
## tax.no_function.py
# Functions
def gets_inputs():
    price = float(input('What is the price '))
    tax = float(input('What is the tax rate? '))
    return price, tax

def calculate_price_with_tax(price, tax):
    return price * (100 + tax) / 100


done = False
while not done:
    sentinel = str.upper(input(f'Enter Q for quit or any other key to compute tax '))
    if sentinel == 'Q':
        done = True
        print(sentinel, done)
        continue
    else:
        print("Compute tax")
        price, tax = get_inputs()
        calculated_price = calculate_price_with_tax(price, tax)
    print(f'The calculated price is {calculated_price}')
# Out:
# Enter Q for quit or any other key to compute tax  Q
# Q True

# %% [markdown]
# **3.** Create a Python module with a function names add_mult(). (refer to L04) slide #18)
# a. Pass in two parameters
# b. Return x + y and x*y
# c. Print the add_mult function while passing in 10, 20
# d. Paste code below

# %%
# add_mult.py
def add_mult(x, y):
    return x + y, x * y

result = add_mult(10,20)
print(result)
# Out:
# (30, 200)

# %% [markdown]
# **4.** (optional - do not have to complete) Rewrite the return.addmult program using a lambda function.
# a. Paste code below:

# %%
# add_mult_lambda.py
add_mult = lambda x, y: (x + y, x * y)

print(add_mult(10, 20))
# Out:
# (30, 200)
